# %% [markdown]
# ## Visualizing Intermediate Activation Functions

# %%
from tensorflow.keras.models import load_model

model = load_model('./models/cats_and_dogs_small_3.h5')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-0ce68e7a336c> in <module>
#       1 from tensorflow.keras.models import load_model
#       2
# ----> 3 model = load_model('./models/cats_and_dogs_small_1.h5')
#       4 model.summary()
#
# /usr/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     109       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     110   else:
# ...

# %% [markdown]
# ## Visualizing ConvNet Filters

# %% [markdown]
# ## Visualizing Class Activation
